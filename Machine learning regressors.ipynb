# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
house = pd.read_csv("/root/data/house_sales.csv")

# %%
house.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.info
# Out:
# <bound method DataFrame.info of                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null int64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
house.shape
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Data visualization

# %%
sns.distplot(house['price'], color = 'green')

# %%
plt.figure(figsize=(15,10))
sns.heatmap(house.corr(), cmap = 'coolwarm', annot=True)

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.scatterplot('sqft_living15', 'price', data=house)

# %%
sns.scatterplot('sqft_living', 'price', data = house)

# %%
sns.boxplot('grade', 'price', data=house)

# %%
plt.scatter('grade', 'price', data = house)

# %%
sns.distplot(house['price'])

# %% [markdown]
# ## Machine learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Linear Regression

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
X = house[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']]

# %%
y = house['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=52)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((15129, 18), (6484, 18), (15129,), (6484,))

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
print("Mean squared error is:", mean_squared_error(y_test, y_pred))
print("Mean absolute error is:", mean_absolute_error(y_test, y_pred))
print("R2 score is:", r2_score(y_test, y_pred))
print("Root mean square:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean squared error is: 40057074437.61655
# Mean absolute error is: 125588.28148385599
# R2 score is: 0.7134946088463813
# Root mean square: 200142.63523201784

# %%
from sklearn.metrics import accuracy_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7134946088463813

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 125588.28148385599

# %%
from sklearn.metrics import classification_report, confusion_matrix # We use this for data which is not continuous

# %%
print("mean Squared error is:", mean_squared_error(y_test, y_pred))
# Out:
# mean Squared error is: 40057074437.61655

# %%
model.coef_
# Out:
# array([-3.56938868e+04,  3.73118404e+04,  1.11753538e+02,  1.21560177e-01,
#         1.11706473e+04,  5.53592282e+05,  5.39402527e+04,  2.60709362e+04,
#         9.55548899e+04,  6.91280178e+01,  4.26255196e+01, -2.67869642e+03,
#         1.92581241e+01, -6.05089337e+02,  6.07786800e+05, -2.04647086e+05,
#         2.34202143e+01, -4.29141884e-01])

# %%
coefficients = pd.DataFrame(model.coef_, X.columns, columns = ["Coefficient values"])
coefficients
# Out:
#                Coefficient values
# bedrooms            -35693.886753
# bathrooms            37311.840371
# sqft_living            111.753538
# sqft_lot                 0.121560
# floors               11170.647316
# waterfront          553592.282052
# view                 53940.252703
# condition            26070.936153
# grade                95554.889941
# sqft_above              69.128018
# sqft_basement           42.625520
# yr_built             -2678.696421
# yr_renovated            19.258124
# zipcode               -605.089337
# lat                 607786.800127
# long               -204647.085992
# sqft_living15           23.420214
# sqft_lot15              -0.429142

# %%
plt.scatter(y_test, y_pred)

# %% [markdown]
# ## Decision Tree

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_pred = dtr.predict(X_test)

# %%
print("Mean absolute error is:", mean_absolute_error(y_test, y_pred))
print("Mean squared error is:", mean_squared_error(y_test, y_pred))
print("Root mean square is (RMSE):", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2_score is:", r2_score(y_test, y_pred))
# Out:
# Mean absolute error is: 100585.07055829735
# Mean squared error is: 33062062364.64902
# Root mean square is (RMSE): 181829.7620430963
# R2_score is: 0.7635259378494759

# %% [markdown]
# Decision tree regressor gives a smaller RMSE than linear regression

# %%
plt.scatter(y_test, y_pred)

# %%
coefficients = pd.DataFrame(dtr.coef_, X.columns, columns = ["Coefficients"])
coeficients
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-776462b232ea> in <module>
# ----> 1 coefficients = pd.DataFrame(dtr.coef_, X.columns, columns = ["Coefficients"])
#       2 coeficients
#
# AttributeError: 'DecisionTreeRegressor' object has no attribute 'coef_'

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(X_train, y_train)

# %%
y_pred = rfr.predict(X_test)
y_pred

# %%
plt.scatter(y_test, y_pred)
plt.title("Scatterplot")
plt.xlabel("y_test")
plt.ylabel("y_pred")

# %%
print("Mean_absolute error is:", mean_absolute_error(y_test, y_pred))
print("Mean squared error is:", mean_squared_error(y_test, y_pred))
print("Root mean squared error is:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 score is:", r2_score(y_test, y_pred))

# %% [markdown]
# Random  forest regressor is better than both decision tree regressor and linear regression

# %% [markdown]
# ## Support vector machine

# %%
from sklearn.svm import SVR

# %%
svm = SVR()

# %%
svm.fit(X_train, y_train)

# %%
y_pred = svm.predict(X_test)
y_pred = y_pred.reshape(-1, 1)

# %%
print("Mean_absolute error is:", mean_absolute_error(y_test, y_pred))
print("Mean squared error is:", mean_squared_error(y_test, y_pred))
print("Root mean squared error is:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 score is:", r2_score(y_test, y_pred))

# %%
plt.scatter(y_test, y_pred)
